# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot([1,2,3,4,5])
plt.ylabel('Some significant Numbers')
plt.show()

# %%
t = np.arange(0.,5.,0.2)

# %%
plt.plot(t,t,'r--', t, t**2, 'gs',t,t**3,'y^')
plt.axis((0,6,0,150))
plt.show()
